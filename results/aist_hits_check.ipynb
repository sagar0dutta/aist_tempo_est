# %%
import os
import ast
import numpy as np
import seaborn as sns
import pandas as pd
from dance_evaluation import *
import matplotlib.pyplot as plt

# %%
foot_df = pd.read_csv(f"./aist_pos1s/foot/foot_zero_uni_70_145.csv")
hand_df = pd.read_csv(f"./aist_pos1s/hand/hand_zero_uni_70_145.csv")

foot_1s_score = pd.read_csv(f"./aist_pos1s/foot/foot_uni_70_145_score.csv")
hand_1s_score = pd.read_csv(f"./aist_pos1s/hand/hand_uni_70_145_score.csv")

foot_2s_score = pd.read_csv(f"./aist_pos2s/foot/foot_uni_70_145_score.csv")
hand_2s_score = pd.read_csv(f"./aist_pos2s/hand/hand_uni_70_145_score.csv")

foot_1s_score["hits_idx"] = foot_1s_score["hits_idx"].apply(ast.literal_eval)
hand_1s_score["hits_idx"] = hand_1s_score["hits_idx"].apply(ast.literal_eval)

foot_2s_score["hits_idx"] = foot_2s_score["hits_idx"].apply(ast.literal_eval)
hand_2s_score["hits_idx"] = hand_2s_score["hits_idx"].apply(ast.literal_eval)

total = foot_df.shape[0]

# %%
foot_df
# Out:
#                         filename dance_genre situation camera_id dancer_id  \
# 0     gKR_sBM_cAll_d28_mKR3_ch03         gKR       sBM      cAll       d28
# 1     gHO_sBM_cAll_d20_mHO5_ch01         gHO       sBM      cAll       d20
# 2     gKR_sBM_cAll_d28_mKR2_ch03         gKR       sBM      cAll       d28
# 3     gPO_sBM_cAll_d10_mPO3_ch03         gPO       sBM      cAll       d10
# 4     gJS_sBM_cAll_d01_mJS3_ch03         gJS       sBM      cAll       d01
# ...                          ...         ...       ...       ...       ...
# 1336  gHO_sFM_cAll_d20_mHO3_ch11         gHO       sFM      cAll       d20
# 1337  gLH_sBM_cAll_d18_mLH5_ch07         gLH       sBM      cAll       d18
# 1338  gWA_sBM_cAll_d26_mWA5_ch03         gWA       sBM      cAll       d26
# 1339  gHO_sBM_cAll_d20_mHO5_ch08         gHO       sBM      cAll       d20
# 1340  gJB_sBM_cAll_d07_mJB1_ch04         gJB       sBM      cAll       d07
#
#      music_id choreo_id  music_tempo     X_a     Y_a  bpm_mode  bpm_median  \
# 0        mKR3      ch03          110  123.00  113.20     113.0       113.0
# 1        mHO5      ch01          135  124.25  137.25     136.0       136.0
# 2        mKR2      ch03          100  116.00  104.60     102.0       109.0
# 3        mPO3      ch03          110  104.60  120.80     126.0       116.5
# 4        mJS3      ch03          110  128.00  114.40     144.0       123.5
# ...       ...       ...          ...     ...     ...       ...         ...
# 1336     mHO3      ch11          125   90.40  123.20      96.0       105.5
# 1337     mLH5      ch07          130  121.00   95.12      95.0        98.5
# 1338     mWA5      ch03          130   90.38  105.62      70.0       107.5
# 1339     mHO5      ch08          135   99.12  100.00     100.0       100.0
# 1340     mJB1      ch04           90   91.00  125.00      96.0       108.0
#
#       mode_x  mode_y  median_x  median_y
# 0      111.0   111.0     113.0     113.0
# 1      136.0   136.0     135.5     135.5
# 2       74.0    74.0     118.0     118.0
# 3       87.0    87.0     110.0     110.0
# 4      122.0   122.0     124.0     124.0
# ...      ...     ...       ...       ...
# 1336    96.0    96.0      96.0      96.0
# 1337    99.0    99.0     125.5     125.5
# 1338    70.0    70.0      90.0      90.0
# 1339   102.0   102.0      99.5      99.5
# 1340    96.0    96.0      95.5      95.5
#
# [1341 rows x 16 columns]

# %%
def calc_hits(foot_score, hand_score):

    foot_hits = set(foot_score)
    hand_hits = set(hand_score)
    combined_hits = foot_hits.union(hand_hits)
    common_hits = foot_hits.intersection(hand_hits)
    
    print("total:", total)
    print("foot hits:", len(foot_hits), f"({round(len(foot_hits)*100/total, 2)} %)" )
    print("hand hits:", len(hand_hits), f"({round(len(hand_hits)*100/total, 2)} %)" )
    print("combined hits:", len(combined_hits), f"({round(len(combined_hits)*100/total, 2)} %)" )
    print("common hits:", len(common_hits))
    print("foot - common:", len(foot_hits)-len(common_hits))
    print("hand - common:", len(hand_hits)-len(common_hits))
    
    return foot_hits, hand_hits, combined_hits, common_hits


print(10*"*"+"1-Sensor"+ 10*"*" )
foot1_hits, hand1_hits, combined1_hits, common1_hits = calc_hits(foot_1s_score["hits_idx"][3], hand_1s_score["hits_idx"][3])

print(10*"*"+"2-Sensor"+ 10*"*" )
foot2_hits, hand2_hits, combined2_hits, common2_hits = calc_hits(foot_2s_score["hits_idx"][3], hand_2s_score["hits_idx"][3])
# Out:
# **********1-Sensor**********
# total: 1341
# foot hits: 585 (43.62 %)
# hand hits: 671 (50.04 %)
# combined hits: 909 (67.79 %)
# common hits: 347
# foot - common: 238
# hand - common: 324
# **********2-Sensor**********
# total: 1341
# foot hits: 566 (42.21 %)
# hand hits: 655 (48.84 %)
# combined hits: 861 (64.21 %)
# common hits: 360
# foot - common: 206
# hand - common: 295

# %%
# hits per dance genre
#
