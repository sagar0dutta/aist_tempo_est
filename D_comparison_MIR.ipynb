# %%
import os, glob
import numpy as np
import librosa
import pickle
import madmom
import essentia.standard as es
from tqdm import tqdm

def load_pickle(filepath):
    with open(filepath, "rb") as f:
        json_data = pickle.load(f)
    return json_data

mp3_path = "aist_dataset/mp3"
mp3_files = sorted(glob.glob(os.path.join(mp3_path, "*.mp3")))

plp_bpms = []
madmom_bpms = []
essentia_bpms = []
percival_bpms = []
madmom_cnn_bpms = []
tempo_cnn_bpms = []

# 1. PLP-based tempo (via librosa)
def estimate_bpm_plp(audio_file, sr=22050):
    
    y, sr = librosa.load(audio_file, sr=sr)
    # Onset strength envelope
    oenv = librosa.onset.onset_strength(y=y, sr=sr)
    # PLP curve
    plp = librosa.beat.plp(onset_envelope=oenv, sr=sr)
    # Convert PLP (Hz) to BPM
    bpm = 60.0 * plp.mean()
    return bpm

# 2. DL baseline using Madmom (RNN + TempoEstimation)
# Böck, S., Krebs, F., & Widmer, G. (2015). Accurate Tempo Estimation Based on Recurrent Neural Networks and Resonating Comb Filters. ISMIR 2015.
rnn_beat = madmom.features.beats.RNNBeatProcessor()
tempo_proc = madmom.features.tempo.TempoEstimationProcessor(fps=100, method='comb')


def estimate_bpm_madmom(audio_file):
    
    act = rnn_beat(audio_file)  # tempo search range is [30, 285] BPM by default
    tempo_arr = tempo_proc(act)
    bpm = tempo_arr[0][0]  # most likely tempo in BPM
    return bpm

# 3. Classical baseline via Essentia
# Zapata, J., Davies, M. E. P., & Serra, X. (2014). Multi-Feature Beat Tracker. IEEE/ACM Transactions on Audio, Speech, and Language Processing, 22(4), 816–825.
rhythm_extractor = es.RhythmExtractor2013(method="multifeature")

def estimate_bpm_essentia(audio_file):
    
    loader = es.MonoLoader(filename=audio_file)
    audio = loader()
    bpm, _, _, _, _ = rhythm_extractor(audio)   # tempo search range is [40, 208] BPM by default    
    return bpm

# 4. Percival's method via Essentia
# Percival, G., & Tzanetakis, G. (2014). Streamlined Tempo Estimation Based on Autocorrelation and Cross-Correlation with Pulses. IEEE/ACM Transactions on Audio, Speech, and Language Processing, 22(12), 1765–1776.
percival_estimator = es.PercivalBpmEstimator(minBPM=60, maxBPM=140)

def estimate_bpm_percival(audio_file):
    
    loader = es.MonoLoader(filename=audio_file)
    audio = loader()
    bpm = percival_estimator(audio)     # tempo search range is [50, 210] BPM by default        
    return bpm

# Schreiber & Müller (ISMIR 2018)
def estimate_bpm_tempocnn(audio_file, model_path="/itf-fi-ml/home/sagardu/aist_tempo_est/deepsquare-k16-3.pb", sr=11025):
    
    # Load audio at the expected rate
    audio = es.MonoLoader(filename=audio_file, sampleRate=sr, resampleQuality=4)()    
    # Load CNN model
    model = es.TempoCNN(graphFilename=model_path)
    global_tempo, local_tempo, local_tempo_probabilities = model(audio)
    return float(global_tempo)


for f in tqdm(mp3_files):
    # print(f"Processing {os.path.basename(f)}")
    # plp_bpms.append(estimate_bpm_plp(f))
    
    madmom_bpms.append(estimate_bpm_madmom(f))
    essentia_bpms.append(estimate_bpm_essentia(f))
    
    bpm_percival = estimate_bpm_percival(f)
    percival_bpms.append(bpm_percival)
    tempo_cnn_bpms.append(estimate_bpm_tempocnn(f))
    

madmom_bpms = np.array(madmom_bpms)
essentia_bpms = np.array(essentia_bpms)
percival_bpms = np.array(percival_bpms)
cnn_bpms = np.array(tempo_cnn_bpms)
# Out:
# 2025-10-06 14:47:52.670495: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-10-06 14:47:52.670542: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# [   INFO   ] MusicExtractorSVM: no classifier models were configured by default
# 2025-10-06 14:47:53.819897: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-06 14:47:53.828218: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2025-10-06 14:47:54.219817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:54.220102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:54.220343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:54.220462: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-10-06 14:47:54.221184: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2025-10-06 14:47:54.221618: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2025-10-06 14:47:54.222051: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2025-10-06 14:47:54.339943: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2025-10-06 14:47:55.081880: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2025-10-06 14:47:55.082752: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2025-10-06 14:47:55.083204: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2025-10-06 14:47:55.083217: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.083259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.083267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.083274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.083280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.083286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.094611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.094889: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.095136: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.095150: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.095177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.095184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.095191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.095197: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.095203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.096578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.096832: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.097075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.097087: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.097105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.097112: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.097119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.097125: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.097131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.598146: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.598424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.598661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.598675: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.598701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.598708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.598715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.598721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.598727: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.604565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.604837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.605077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.605091: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.605115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.605123: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.605130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.605136: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.605142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.607991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.608249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.608484: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.608496: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.608519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.608526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.608532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.608539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.608545: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.614316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.614593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.614835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.614847: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.614869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.614877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.614884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.614890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.614896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.615525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.615769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.616012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.616024: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.616042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.616050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.616057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.616063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.616069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.617312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.617568: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.617798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.617816: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.617833: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.617840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.617847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.617853: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.617859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.619223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.619465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.619694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.619705: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.619721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.619728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.619735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.619741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.619747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.620967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.621217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.621439: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.621450: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.621466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.621473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.621479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.621485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.621491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.623670: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.623913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.624138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.624148: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.624164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.624171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.624178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.624184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.624190: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.626981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.627247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.627482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.627494: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.627511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.627518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.627525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.627531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.627537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.630671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.630918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.631143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.631154: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.631173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.631180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.631186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.631192: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.631198: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.634139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.634378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.634603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.634615: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.634633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.634640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.634646: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.634652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.634658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.637936: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.638220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.638465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.638478: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.638499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.638507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.638514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.638521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.638527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.645573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.645852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.646089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.646102: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.646128: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.646135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.646142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.646148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.646154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.654899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.655175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.655414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.655427: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.655453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.655461: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.655468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.655474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.655480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.660153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.660411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.660643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.660656: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.660678: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.660687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.660694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.660700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.660705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.663813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.664070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.664301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.664313: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.664333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.664341: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.664348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.664354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.664359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.667163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.667419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.667683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.667695: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.667715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.667723: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.667730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.667736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.667742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.671345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.671615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.671862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.671875: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.671899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.671906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.671914: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.671920: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.671926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:47:55.675247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.675509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.675746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:47:55.675758: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:47:55.675780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:47:55.675788: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:47:55.675795: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:47:55.675801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:47:55.675814: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# /itf-fi-ml/home/sagardu/miniconda3/lib/python3.12/site-packages/madmom/features/tempo.py:724: UserWarning: Usage of `method` is deprecated as of version 0.17. Please pass a dedicated `TempoHistogramProcessor` instance as `histogram_processor`.Functionality will be removed in version 0.19.
#   warnings.warn(
#   0%|          | 0/60 [00:00<?, ?it/s][   INFO   ] On connection Flux::flux → IIR::signal:
# [   INFO   ] BUFFER SIZE MISMATCH: max=0 - asked for read size 4096
# [   INFO   ] resizing buffer to 36040/4505
# [   INFO   ] FrameCutter: dropping incomplete frame
# 2025-10-06 14:48:11.899280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:48:11.899621: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:48:11.899901: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:48:11.899944: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:48:11.900001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:48:11.900009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:48:11.900016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:48:11.900023: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:48:11.900029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:48:11.904979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
#   2%|▏         | 1/60 [00:15<15:12, 15.47s/it]y: 7.5 Ti computeCapabilit
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:48:11.905274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:48:11.905529: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:48:11.905544: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# ...
# 2025-10-06 14:56:23.564574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:23.564585: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:23.564603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:23.564610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:23.564616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:23.564622: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:23.564628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `/itf-fi-ml/home/sagardu/aist_tempo_est/deepsquare-k16-3.pb`
# 2025-10-06 14:56:23.576857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:23.577142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:23.577408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:23.577420: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:23.577446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:23.577453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:23.577460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:23.577466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:23.577472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:56:23.743614: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:23.744129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:23.744619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:23.744649: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:23.744697: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:23.744714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:23.744729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:23.744743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:23.744756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:56:30.089436: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 100%|██████████| 60/60 [08:33<00:00,  7.55s/it]2025-10-06 14:56:30.089833: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.090097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.090112: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:30.090144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:30.090152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:30.090159: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:30.090166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:30.090172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:56:30.094330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.094623: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# 100%|██████████| 60/60 [08:33<00:00,  8.55s/it]y: 7.5Ti computeCapabilit
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.094902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.094916: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:30.094939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:30.094947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:30.094954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:30.094961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:30.094968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:56:30.098648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.098930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.099176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.099190: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:30.099211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:30.099218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:30.099225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:30.099231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:30.099237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:56:30.102648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.102912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.103153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwid
# th: 573.69GiB/s
# 2025-10-06 14:56:30.103165: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:30.103182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:30.103190: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:30.103196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:30.103202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:30.103208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `/itf-fi-ml/home/sagardu/aist_tempo_est/deepsquare-k16-3.pb`
# 2025-10-06 14:56:30.115724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.116027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.116282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.116295: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:30.116321: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:30.116329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:30.116335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:30.116342: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:30.116348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N
# 2025-10-06 14:56:30.247672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:18:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.247990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.248249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:86:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2025-10-06 14:56:30.248263: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-10-06 14:56:30.248290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-06 14:56:30.248297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2
# 2025-10-06 14:56:30.248304: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N
# 2025-10-06 14:56:30.248310: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N
# 2025-10-06 14:56:30.248316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N

# %%
def compute_dts(
    ref_bpm,
    estimated_bpm,
    tau=0.06,
    mode="one"
):

    ref_bpm = np.asarray(ref_bpm, dtype=float)

    # select a single estimate per index if needed
    if mode == "many":
        # estimated_bpm is e.g. [(b1, b2,...), (c1, c2,...), ...]
        chosen = np.array([
            min(cands, key=lambda b: abs(b - ref_bpm[i]))
            for i, cands in enumerate(estimated_bpm)
        ], dtype=float)
    elif mode == "one":
        chosen = np.asarray(estimated_bpm, dtype=float)
    else:
        raise ValueError(f"Unknown mode: {mode!r}. Use 'one' or 'many'.")

    # now compute the DTS exactly as before
    e = np.log2(chosen / ref_bpm)
    # distance from nearest of -1, 0, +1
    d = np.abs(e[:, None] - np.array([-1.0, 0.0, 1.0])).min(axis=1)
    # clip by tolerance and convert to score
    d_clip = np.minimum(d, tau)
    dts    = 1.0 - d_clip / tau

    accuracy = (dts > 0.0).mean() * 100
    
    # hits ----------------------------------------------------------
    hit_mask = dts > 0.0          # inside ±tau band
    hit_idx = np.nonzero(hit_mask)[0]
    ref_hit_bpm = ref_bpm[hit_idx]
    
    return dts, e, d, accuracy

# %%
ref_dict = {    "mBR0": 80,    "mBR1": 90,    "mBR2": 100,    "mBR3": 110,    "mBR4": 120,
    "mBR5": 130,    "mPO0": 80,    "mPO1": 90,    "mPO2": 100,    "mPO3": 110,    "mPO4": 120,
    "mPO5": 130,    "mLO0": 80,    "mLO1": 90,    "mLO2": 100,    "mLO3": 110,    "mLO4": 120,
    "mLO5": 130,    "mMH0": 80,    "mMH1": 90,    "mMH2": 100,    "mMH3": 110,    "mMH4": 120,
    "mMH5": 130,    "mLH0": 80,    "mLH1": 90,    "mLH2": 100,    "mLH3": 110,    "mLH4": 120,
    "mLH5": 130,    "mHO0": 110,    "mHO1": 115,    "mHO2": 120,    "mHO3": 125,    "mHO4": 130,
    "mHO5": 135,    "mWA0": 80,    "mWA1": 90,    "mWA2": 100,    "mWA3": 110,    "mWA4": 120,
    "mWA5": 130,    "mKR0": 80,    "mKR1": 90,    "mKR2": 100,    "mKR3": 110,    "mKR4": 120,
    "mKR5": 130,    "mJS0": 80,    "mJS1": 90,    "mJS2": 100,    "mJS3": 110,    "mJS4": 120,
    "mJS5": 130,    "mJB0": 80,    "mJB1": 90,    "mJB2": 100,    "mJB3": 110,    "mJB4": 120,    "mJB5": 130
}

# Build reference array
file_ids = [os.path.splitext(os.path.basename(f))[0] for f in mp3_files]
ref = np.array([ref_dict[fid] for fid in file_ids])

ta = 0.05

# _, _, _, accuracy_plp  = compute_dts(ref, plp_bpms, tau= ta, mode="one")
_, _, _, accuracy_madmom  = compute_dts(ref, madmom_bpms, tau= ta, mode="one")
_, _, _, accuracy_essentia  = compute_dts(ref, essentia_bpms, tau= ta, mode="one")
_, _, _, accuracy_percival  = compute_dts(ref, percival_bpms, tau= ta, mode="one")
_, _, _, accuracy_cnn  = compute_dts(ref, cnn_bpms, tau= ta, mode="one")


print("=== Tempo Estimation Accuracy with DTS (±3.5%) ===")
print(f"Accuracy Essentia: {accuracy_essentia:.2f}%")
print(f"Accuracy Madmom: {accuracy_madmom:.2f}%")
print(f"Accuracy Percival: {accuracy_percival:.2f}%")
print(f"Accuracy TempoCNN: {accuracy_cnn:.2f}%")
# Out:
# === Tempo Estimation Accuracy with DTS (±3.5%) ===
# Accuracy Essentia: 98.33%
# Accuracy Madmom: 100.00%
# Accuracy Percival: 15.00%
# Accuracy TempoCNN: 98.33%

# %%
import numpy as np

def tempo_accuracy(ref, est, tol=0.035):
    """
    Compute Accuracy1 and Accuracy2 for tempo estimation.
    
    Parameters
    ----------
    ref : array-like
        Reference tempi (BPM)
    est : array-like
        Estimated tempi (BPM)
    tol : float
        Relative tolerance (default 0.04 = ±4%)
    """
    ref = np.asarray(ref)
    est = np.asarray(est)

    # --- Accuracy1: strict match within tol ---
    correct1 = np.abs(est - ref) / ref <= tol
    acc1 = np.mean(correct1)

    # --- Accuracy2: allow octave errors (x0.5, x2) ---
    correct2 = []
    for r, e in zip(ref, est):
        rel_err = [abs(e - r) / r,
                   abs(2*e - r) / r,
                   abs(0.5*e - r) / r]
        correct2.append(np.min(rel_err) <= tol)
    acc2 = np.mean(correct2)

    return acc1, acc2

# %%
# acc1_plp, acc2_plp = tempo_accuracy(ref, plp_bpms, tol=0.04)
acc1_madmom, acc2_madmom = tempo_accuracy(ref, madmom_bpms, tol=0.04)
acc1_ess, acc2_ess = tempo_accuracy(ref, essentia_bpms, tol=0.04)
acc1_percival, acc2_percival = tempo_accuracy(ref, percival_bpms, tol=0.04)
acc1_cnn, acc2_cnn = tempo_accuracy(ref, cnn_bpms, tol=0.04)

print("=== Tempo Estimation Accuracy with Accuracy1 and Accuracy2 (±3.5%) ===")

print("Madmom - Acc1:", acc1_madmom, "Acc2:", acc2_madmom)
print("Essentia - Acc1:", acc1_ess, "Acc2:", acc2_ess)
print("Percival - Acc1:", acc1_percival, "Acc2:", acc2_percival)
print("TempoCNN - Acc1:", acc1_cnn, "Acc2:", acc2_cnn)
# Out:
# === Tempo Estimation Accuracy with Accuracy1 and Accuracy2 (±3.5%) ===
# Madmom - Acc1: 0.9333333333333333 Acc2: 1.0
# Essentia - Acc1: 0.8666666666666667 Acc2: 0.9833333333333333
# Percival - Acc1: 0.15 Acc2: 0.15
# TempoCNN - Acc1: 0.9833333333333333 Acc2: 0.9833333333333333

# %%
a, b = 60, 140
root = "/itf-fi-ml/home/sagardu/aist_tempo_est/saved_result_adaptive"
pth_pos = f"{root}/tempo_{a}_{b}/pos"

for fname in os.listdir(pth_pos):
    if fname == f"adaptv_Bhandfoot_y_zero_uni_W5_H2.5_{a}_{b}.pkl":
    
        print(f"Processing {fname}...")
        tag = fname.split("_zero_uni")[0]
        data = load_pickle(f"{pth_pos}/{fname}")
        ref  = data["music_tempo"].to_numpy()

# data["bpm_median"]  # dance tempo estimates
# data["music_id"]    # music IDs corresponding to the estimates
# Out:
# Processing adaptv_Bhandfoot_y_zero_uni_W5_H2.5_60_140.pkl...

# %%
# Get music IDs (without extension)
music_ids = [os.path.splitext(os.path.basename(f))[0] for f in mp3_files]

# Build dicts for lookup
plp_dict = dict(zip(music_ids, plp_bpms))
madmom_dict = dict(zip(music_ids, madmom_bpms))
essentia_dict = dict(zip(music_ids, essentia_bpms))
percival_dict = dict(zip(music_ids, percival_bpms))
cnn_dict = dict(zip(music_ids, cnn_bpms))

# %%
dance_ids = data["music_id"]        # length ~1300
dance_bpms = data["bpm_mode"]     # length ~1300

# For each dance entry, fetch corresponding MIR tempo
# plp_for_dance = np.array([plp_dict[mid] for mid in dance_ids])
madmom_for_dance = np.array([madmom_dict[mid] for mid in dance_ids])
essentia_for_dance = np.array([essentia_dict[mid] for mid in dance_ids])
percival_for_dance = np.array([percival_dict[mid] for mid in dance_ids])
cnn_for_dance = np.array([cnn_dict[mid] for mid in dance_ids])

# %%
def agreement_rate(dance_est, mir_est, tol=0.04):
    dance_est, mir_est = np.asarray(dance_est), np.asarray(mir_est)
    # Strict agreement (Acc1)
    acc1 = np.mean(np.abs(dance_est - mir_est) / mir_est <= tol)
    # Agreement with octave flexibility (Acc2)
    acc2 = np.mean([
        min(abs(d - m) / m, abs(2*d - m) / m, abs(0.5*d - m) / m) <= tol
        for d, m in zip(dance_est, mir_est)
    ])
    return acc1, acc2

def confusion_levels(est, ref, tol=0.04):
    categories = []
    for e, r in zip(est, ref):
        if abs(e - r) / r <= tol:
            categories.append("on-time")
        elif abs(e - 0.5*r) / r <= tol:
            categories.append("half-time")
        elif abs(e - 2*r) / r <= tol:
            categories.append("double-time")
        else:
            categories.append("off-grid")
    return categories

# %%
# acc1_plp, acc2_plp = agreement_rate(dance_bpms, plp_for_dance)
acc1_madmom, acc2_madmom = agreement_rate(dance_bpms, madmom_for_dance)
acc1_ess, acc2_ess = agreement_rate(dance_bpms, essentia_for_dance)
acc1_percival, acc2_percival = agreement_rate(dance_bpms, np.array([percival_dict[mid] for mid in dance_ids]))
acc1_cnn, acc2_cnn = agreement_rate(dance_bpms, cnn_for_dance)


print("\n=== Agreement with Audio (Dance vs MIR) ===")

print(f"Madmom  → Acc1: {acc1_madmom:.3f}, Acc2: {acc2_madmom:.3f}")
print(f"Essentia→ Acc1: {acc1_ess:.3f}, Acc2: {acc2_ess:.3f}")
print(f"Percival→ Acc1: {acc1_percival:.3f}, Acc2: {acc2_percival:.3f}")
print(f"TempoCNN→ Acc1: {acc1_cnn:.3f}, Acc2: {acc2_cnn:.3f}")
# Out:
# === Agreement with Audio (Dance vs MIR) ===
# Madmom  → Acc1: 0.412, Acc2: 0.462
# Essentia→ Acc1: 0.362, Acc2: 0.444
# Percival→ Acc1: 0.094, Acc2: 0.094
# TempoCNN→ Acc1: 0.411, Acc2: 0.440

# %%
ref_dict_full = {mid: bpm for mid, bpm in ref_dict.items()}  # your dict
ref_for_dance = np.array([ref_dict_full[mid] for mid in dance_ids])

# Confusion analysis
dance_conf = confusion_levels(dance_bpms, ref_for_dance)
madmom_conf = confusion_levels(madmom_for_dance, ref_for_dance)
ess_conf   = confusion_levels(essentia_for_dance, ref_for_dance)
percival_conf = confusion_levels(percival_for_dance, ref_for_dance)
tempocnn_conf = confusion_levels(cnn_for_dance, ref_for_dance)

# %%
from collections import Counter

def print_confusion(label, conf_list):
    counts = Counter(conf_list)
    total = sum(counts.values())
    print(f"\n{label} confusion:")
    for cat in ["half-time", "on-time", "double-time", "off-grid"]:
        print(f"  {cat:10s}: {counts[cat]:4d} ({counts[cat]/total:.2%})")

print("\n=== Confusion Across Metrical Levels ===")
print_confusion("Dance", dance_conf)
print_confusion("Madmom", madmom_conf)
print_confusion("Essentia", ess_conf)
print_confusion("Percival", percival_conf)
print_confusion("TempoCNN", tempocnn_conf)

# %% [markdown]
# # By Genre

# %%
import json

with open("genre_symbols_mapping.json", "r") as f:
    genre_symbols = json.load(f)

with open("genreID_count_mapping.json", "r") as f:
    genre_counts = json.load(f)

# %%
dance_bpms   = data["bpm_median"].to_numpy()
dance_ids    = data["music_id"].to_numpy()
dance_genres = data["dance_genre"].to_numpy()

ref_for_dance = np.array([ref_dict[mid] for mid in dance_ids])

# %%
from collections import defaultdict

agreement_by_genre = defaultdict(dict)

for g in np.unique(dance_genres):
    mask = dance_genres == g
    ref_g   = ref_for_dance[mask]
    dance_g = dance_bpms[mask]
    
    # MIR-aligned estimates for this subset
 
    madmom_g  = madmom_for_dance[mask]
    ess_g     = essentia_for_dance[mask]
    percival_g= percival_for_dance[mask]

    agreement_by_genre[g]["Madmom"]   = agreement_rate(dance_g, madmom_g)
    agreement_by_genre[g]["Essentia"] = agreement_rate(dance_g, ess_g)
    agreement_by_genre[g]["Percival"] = agreement_rate(dance_g, percival_g)
    agreement_by_genre[g]["TempoCNN"] = agreement_rate(dance_g, cnn_for_dance[mask])

# %%
confusion_by_genre = defaultdict(dict)

for g in np.unique(dance_genres):
    mask = dance_genres == g
    ref_g   = ref_for_dance[mask]
    dance_g = dance_bpms[mask]


    madmom_g  = madmom_for_dance[mask]
    ess_g     = essentia_for_dance[mask]
    percival_g= percival_for_dance[mask]


    confusion_by_genre[g]["Dance"]    = confusion_levels(dance_g, ref_g)
    confusion_by_genre[g]["Madmom"]   = confusion_levels(madmom_g, ref_g)
    confusion_by_genre[g]["Essentia"] = confusion_levels(ess_g, ref_g)
    confusion_by_genre[g]["Percival"] = confusion_levels(percival_g, ref_g)
    confusion_by_genre[g]["TempoCNN"] = confusion_levels(cnn_for_dance[mask], ref_g)

# %%
print("\n=== Agreement by Genre ===")
for g in agreement_by_genre:
    gname = genre_symbols.get(g, g)
    print(f"\n{gname} ({genre_counts.get(g, 0)} sequences):")
    for method, (acc1, acc2) in agreement_by_genre[g].items():
        print(f"  {method:10s} Acc1: {acc1:.3f}, Acc2: {acc2:.3f}")

# print("\n=== Confusion by Genre ===")
# for g in confusion_by_genre:
#     gname = genre_symbols.get(g, g)
#     print(f"\n{gname} ({genre_counts.get(g, 0)} sequences):")
#     for method, conf in confusion_by_genre[g].items():
#         c = Counter(conf); N = sum(c.values())
#         print(f"  {method:10s}", end=" ")
#         for cat in ["half-time", "on-time", "double-time", "off-grid"]:
#             print(f"{cat}:{c[cat]/N:.2%}", end="  ")
#         print()
# Out:
# === Agreement by Genre ===
#
# Break (99 sequences):
#   Madmom     Acc1: 0.778, Acc2: 0.788
#   Essentia   Acc1: 0.677, Acc2: 0.798
#   Percival   Acc1: 0.101, Acc2: 0.101
#   TempoCNN   Acc1: 0.778, Acc2: 0.788
#
# House (136 sequences):
#   Madmom     Acc1: 0.978, Acc2: 0.978
#   Essentia   Acc1: 0.978, Acc2: 0.978
#   Percival   Acc1: 0.000, Acc2: 0.000
#   TempoCNN   Acc1: 0.978, Acc2: 0.978
#
# Ballet Jazz (136 sequences):
#   Madmom     Acc1: 0.169, Acc2: 0.243
#   Essentia   Acc1: 0.206, Acc2: 0.265
#   Percival   Acc1: 0.088, Acc2: 0.088
#   TempoCNN   Acc1: 0.257, Acc2: 0.272
#
# Street Jazz (129 sequences):
#   Madmom     Acc1: 0.178, Acc2: 0.186
#   Essentia   Acc1: 0.178, Acc2: 0.186
#   Percival   Acc1: 0.031, Acc2: 0.031
#   TempoCNN   Acc1: 0.178, Acc2: 0.186
#
# Krump (137 sequences):
#   Madmom     Acc1: 0.489, Acc2: 0.511
#   Essentia   Acc1: 0.453, Acc2: 0.511
#   Percival   Acc1: 0.029, Acc2: 0.029
#   TempoCNN   Acc1: 0.482, Acc2: 0.504
#
# LA style Hip-hop (141 sequences):
#   Madmom     Acc1: 0.560, Acc2: 0.567
#   Essentia   Acc1: 0.574, Acc2: 0.582
#   Percival   Acc1: 0.028, Acc2: 0.028
#   TempoCNN   Acc1: 0.574, Acc2: 0.582
#
# Lock (141 sequences):
#   Madmom     Acc1: 0.383, Acc2: 0.383
#   Essentia   Acc1: 0.369, Acc2: 0.390
#   Percival   Acc1: 0.021, Acc2: 0.021
#   TempoCNN   Acc1: 0.397, Acc2: 0.397
#
# Middle Hip-hop (140 sequences):
#   Madmom     Acc1: 0.664, Acc2: 0.779
#   Essentia   Acc1: 0.550, Acc2: 0.786
#   Percival   Acc1: 0.107, Acc2: 0.107
#   TempoCNN   Acc1: 0.643, Acc2: 0.643
#
# Pop (141 sequences):
#   Madmom     Acc1: 0.426, Acc2: 0.447
#   Essentia   Acc1: 0.447, Acc2: 0.447
#   Percival   Acc1: 0.021, Acc2: 0.021
#   TempoCNN   Acc1: 0.440, Acc2: 0.440
#
# Waack (141 sequences):
#   Madmom     Acc1: 0.206, Acc2: 0.206
#   Essentia   Acc1: 0.227, Acc2: 0.227
#   Percival   Acc1: 0.000, Acc2: 0.000
#   TempoCNN   Acc1: 0.227, Acc2: 0.227
